# %%
import tensorflow as tf

# %%
tf.enable_eager_execution()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-ddf3115bdcc7> in <module>
# ----> 1 tf.enable_eager_execution()
#
# AttributeError: module 'tensorflow' has no attribute 'enable_eager_execution'

# %%
tf.__version__
# Out:
# '1.15.0'

# %%
# A comma-delimited list of the words you want to train for.
# The options are: yes,no,up,down,left,right,on,off,stop,go
# All the other words will be used to train an "unknown" label and silent
# audio data with no spoken words will be used to train a "silence" label.
WANTED_WORDS = "one,two,three,four,five"

# The number of steps and learning rates can be specified as comma-separated
# lists to define the rate at each stage. For example,
# TRAINING_STEPS=12000,3000 and LEARNING_RATE=0.001,0.0001
# will run 12,000 training loops in total, with a rate of 0.001 for the first
# 8,000, and 0.0001 for the final 3,000.
TRAINING_STEPS = "10000,10000,10000"
LEARNING_RATE = "0.001,0.0001,0.0001"

# Calculate the total number of steps, which is used to identify the checkpoint
# file name.
TOTAL_STEPS = str(sum(map(lambda string: int(string), TRAINING_STEPS.split(","))))

# Print the configuration to confirm it
print("Training these words: %s" % WANTED_WORDS)
print("Training steps in each stage: %s" % TRAINING_STEPS)
print("Learning rate in each stage: %s" % LEARNING_RATE)
print("Total number of training steps: %s" % TOTAL_STEPS)
# Out:
# Training these words: one,two,three,four,five
# Training steps in each stage: 10000,10000,10000
# Learning rate in each stage: 0.001,0.0001,0.0001
# Total number of training steps: 30000

# %%
number_of_labels = WANTED_WORDS.count(',') + 1
number_of_total_labels = number_of_labels + 2 # for 'silence' and 'unknown' label
equal_percentage_of_training_samples = int(100.0/(number_of_total_labels))
SILENT_PERCENTAGE = equal_percentage_of_training_samples
UNKNOWN_PERCENTAGE = equal_percentage_of_training_samples

# Constants which are shared during training and inference
PREPROCESS = 'micro'
WINDOW_STRIDE = 20
MODEL_ARCHITECTURE = 'conv' # Other options include: single_fc, conv,
                      # low_latency_conv, low_latency_svdf, tiny_embedding_conv

# Constants used during training only
VERBOSITY = 'WARN'
EVAL_STEP_INTERVAL = '1000'
SAVE_STEP_INTERVAL = '1000'

# Constants for training directories and filepaths
DATASET_DIR =  'dataset/'
LOGS_DIR = 'logs/'
TRAIN_DIR = 'train/' # for training checkpoints and other files.

# Constants for inference directories and filepaths
import os
MODELS_DIR = 'models2cnn1maxpool1fc'
if not os.path.exists(MODELS_DIR):
  os.mkdir(MODELS_DIR)
MODEL_TF = os.path.join(MODELS_DIR, 'model.pb')
MODEL_TFLITE = os.path.join(MODELS_DIR, 'model.tflite')
FLOAT_MODEL_TFLITE = os.path.join(MODELS_DIR, 'float_model.tflite')
MODEL_TFLITE_MICRO = os.path.join(MODELS_DIR, 'model.cc')
SAVED_MODEL = os.path.join(MODELS_DIR, 'saved_model')

QUANT_INPUT_MIN = 0.0
QUANT_INPUT_MAX = 26.0
QUANT_INPUT_RANGE = QUANT_INPUT_MAX - QUANT_INPUT_MIN

# %%
# %tensorflow_version 1.x
import tensorflow as tf

# %%
# !which python

# %%
# !rm -rf dataset

# %%
os.getcwd()

# %%
# !/home/aml/anaconda3/envs/prakasha3.6/bin/python train.py \
--data_dir={DATASET_DIR} \
--wanted_words={WANTED_WORDS} \
--silence_percentage={SILENT_PERCENTAGE} \
--unknown_percentage={UNKNOWN_PERCENTAGE} \
--preprocess={PREPROCESS} \
--window_stride={WINDOW_STRIDE} \
--model_architecture='conv' \
--how_many_training_steps={TRAINING_STEPS} \
--learning_rate={LEARNING_RATE} \
--train_dir={TRAIN_DIR} \
--summaries_dir={LOGS_DIR} \
--eval_step_interval={EVAL_STEP_INTERVAL} \
--save_step_interval={SAVE_STEP_INTERVAL}
# Out:
# 2021-05-21 09:54:55.316247: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-05-21 09:54:55.326348: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2800000000 Hz
# 2021-05-21 09:54:55.328257: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a99e26bff0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-21 09:54:55.328286: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-21 09:54:55.330668: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/lsf_10.1.0/10.1/linux3.10-glibc2.17-x86_64/lib:/opt/cuda/cuda/cuda-10.1/lib64/:/opt/cuda/cuda/cuda-10.1/extras/CUPTI/lib64/:/usr/local/lib
# 2021-05-21 09:54:55.330697: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-05-21 09:54:55.330717: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (vihlc2076): /proc/driver/nvidia/version does not exist
# WARNING:tensorflow:From /home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0521 09:55:00.452188 139994633164608 deprecation.py:323] From /home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ada
# INFO:tensorflow:Training from step: 1
# I0521 09:55:00.764237 139994633164608 train.py:218] Training from step: 1
# INFO:tensorflow:Step #1000: rate 0.001000, accuracy 75.0%, cross entropy 0.816549
# I0521 09:59:15.285654 139994633164608 train.py:269] Step #1000: rate 0.001000, accuracy 75.0%, cross entropy 0.816549
# INFO:tensorflow:Confusion Matrix:
#  [[248   1   0   2   0   0   0]
#  [ 10  89   4  80  13  26  29]
#  [  6  18 198  13   7  56  53]
#  [  5   8   0 324   0   4   4]
#  [  6  11   0  24 286   0  29]
#  [  2  13   3  59   1 289   6]
#  [  6   9   2  10  12  12 316]]
# I0521 09:59:20.364589 139994633164608 train.py:293] Confusion Matrix:
#  [[248   1   0   2   0   0   0]
#  [ 10  89   4  80  13  26  29]
#  [  6  18 198  13   7  56  53]
#  [  5   8   0 324   0   4   4]
#  [  6  11   0  24 286   0  29]
#  [  2  13   3  59   1 289   6]
#  [  6   9   2  10  12  12 316]]
# INFO:tensorflow:Step 1000: Validation accuracy = 76.3% (N=2294)
# I0521 09:59:20.364860 139994633164608 train.py:295] Step 1000: Validation accuracy = 76.3% (N=2294)
# INFO:tensorflow:Saving to "train/conv.ckpt-1000"
# I0521 09:59:20.364938 139994633164608 train.py:303] Saving to "train/conv.ckpt-1000"
# INFO:tensorflow:Step #2000: rate 0.001000, accuracy 78.0%, cross entropy 0.820781
# I0521 10:03:36.631619 139994633164608 train.py:269] Step #2000: rate 0.001000, accuracy 78.0%, cross entropy 0.820781
# INFO:tensorflow:Confusion Matrix:
#  [[251   0   0   0   0   0   0]
#  [ 37  63   9 107   5  14  16]
#  [ 10  21 284  14   0   4  18]
#  [ 23   1   0 321   0   0   0]
#  [ 13  19   1  37 249   0  37]
#  [ 15  11  16  68   0 257   6]
#  [ 16  11   3  16   3   3 315]]
# I0521 10:03:42.235172 139994633164608 train.py:293] Confusion Matrix:
#  [[251   0   0   0   0   0   0]
#  [
(N=2294)
# INFO:tensorflow:Saving to "train/conv.ckpt-27000"
# I0521 12:03:35.802542 139994633164608 train.py:303] Saving to "train/conv.ckpt-27000"
# INFO:tensorflow:Step #28000: rate 0.000100, accuracy 79.0%, cross entropy 0.524463
# I0521 12:08:15.615695 139994633164608 train.py:269] Step #28000: rate 0.000100, accuracy 79.0%, cross entropy 0.524463
# INFO:tensorflow:Confusion Matrix:
#  [[251   0   0   0   0   0   0]
#  [ 38  72  16  88   4  12  21]
#  [  7   6 320   3   1   6   8]
#  [ 12   3   0 329   1   0   0]
#  [ 11  16   1  25 280   0  23]
#  [  5   6   8  72   0 277   5]
#  [ 13  11   4  13   0   1 325]]
# I0521 12:08:21.855080 139994633164608 train.py:293] Confusion Matrix:
#  [[251   0   0   0   0   0   0]
#  [ 38  72  16  88   4  12  21]
#  [  7   6 320   3   1   6   8]
#  [ 12   3   0 329   1   0   0]
#  [ 11  16   1  25 280   0  23]
#  [  5   6   8  72   0 277   5]
#  [ 13  11   4  13   0   1 325]]
# INFO:tensorflow:Step 28000: Validation accuracy = 80.8% (N=2294)
# I0521 12:08:21.855334 139994633164608 train.py:295] Step 28000: Validation accuracy = 80.8% (N=2294)
# INFO:tensorflow:Saving to "train/conv.ckpt-28000"
# I0521 12:08:21.855395 139994633164608 train.py:303] Saving to "train/conv.ckpt-28000"
# INFO:tensorflow:Step #29000: rate 0.000100, accuracy 85.0%, cross entropy 0.423099
# I0521 12:12:40.935698 139994633164608 train.py:269] Step #29000: rate 0.000100, accuracy 85.0%, cross entropy 0.423099
# INFO:tensorflow:Confusion Matrix:
#  [[251   0   0   0   0   0   0]
#  [ 38  73  13  80   5  19  23]
#  [  9   4 318   3   1   7   9]
#  [ 12   3   0 328   1   1   0]
#  [  7  15   1  22 289   0  22]
#  [  4   5   7  65   1 284   7]
#  [ 11   6   4  15   1   4 326]]
# I0521 12:12:45.863147 139994633164608 train.py:293] Confusion Matrix:
#  [[251   0   0   0   0   0   0]
#  [ 38  73  13  80   5  19  23]
#  [  9   4 318   3   1   7   9]
#  [ 12   3   0 328   1   1   0]
#  [  7  15   1  22 289   0  22]
#  [  4   5   7  65   1 284   7]
#  [ 11   6   4  15   1   4 326]]
# INFO:tensorflow:Step 29000: Validation accuracy = 81.5% (N=2294)
# I0521 12:12:45.863401 139994633164608 train.py:295] Step 29000: Validation accuracy = 81.5% (N=2294)
# INFO:tensorflow:Saving to "train/conv.ckpt-29000"
# I0521 12:12:45.863459 139994633164608 train.py:303] Saving to "train/conv.ckpt-29000"
# 2021-05-21 12:12:45.874532: W tensorflow/core/framework/op_kernel.cc:1651] OP_REQUIRES failed at save_restore_v2_ops.cc:137 : Resource exhausted: train/conv.ckpt-29000.data-00000-of-00001.tempstate928252165646262985; No space left on device
# Traceback (most recent call last):
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: train/conv.ckpt-29000.data-00000-of-00001.tempstate928252165646262985; No space left on device
# 	 [[{{node save/SaveV2}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "train.py", line 519, in <module>
#     tf.compat.v1.app.run(main=main, argv=[sys.argv[0]] + unparsed)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "train.py", line 304, in main
#     saver.save(sess, checkpoint_path, global_step=training_step)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 1176, in save
#     {self.saver_def.filename_tensor_name: checkpoint_file})
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/client/session.py", line 1384, in _do_call
#     raise type(e)(node_def, op, message)
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: train/conv.ckpt-29000.data-00000-of-00001.tempstate928252165646262985; No space left on device
# 	 [[node save/SaveV2 (defined at /home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py:1748) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Original stack trace for 'save/SaveV2':
#   File "train.py", line 519, in <module>
#     tf.compat.v1.app.run(main=main, argv=[sys.argv[0]] + unparsed)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "train.py", line 201, in main
#     saver = tf.compat.v1.train.Saver(tf.compat.v1.global_variables())
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 828, in __init__
#     self.build()
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 840, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 878, in _build
#     build_restore=build_restore)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 505, in _build_internal
#     save_tensor = self._AddSaveOps(filename_tensor, saveables)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 206, in _AddSaveOps
#     save = self.save_op(filename_tensor, saveables)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py", line 122, in save_op
#     tensors)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_io_ops.py", line 1946, in save_v2
#     name=name)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
SAVED_MODEL
# Out:
# 'models2cnn1maxpool1fc/saved_model'

# %%
# !/home/aml/anaconda3/envs/prakasha3.6/bin/python freeze.py \
--wanted_words=$WANTED_WORDS \
--window_stride_ms=$WINDOW_STRIDE \
--preprocess=$PREPROCESS \
--model_architecture='conv' \
--start_checkpoint=$TRAIN_DIR$MODEL_ARCHITECTURE'.ckpt-'{TOTAL_STEPS} \
--save_format=saved_model \
--output_file={SAVED_MODEL}
# Out:
# 2021-05-21 09:42:52.487179: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-05-21 09:42:52.496311: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2800000000 Hz
# 2021-05-21 09:42:52.498368: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x560525ab0590 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-21 09:42:52.498404: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-21 09:42:52.500780: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/lsf_10.1.0/10.1/linux3.10-glibc2.17-x86_64/lib:/opt/cuda/cuda/cuda-10.1/lib64/:/opt/cuda/cuda/cuda-10.1/extras/CUPTI/lib64/:/usr/local/lib
# 2021-05-21 09:42:52.500803: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-05-21 09:42:52.500825: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (vihlc2076): /proc/driver/nvidia/version does not exist
# INFO:tensorflow:Restoring parameters from train/conv.ckpt-3000
# I0521 09:42:52.563544 140375794652992 saver.py:1284] Restoring parameters from train/conv.ckpt-3000
# WARNING:tensorflow:From freeze.py:235: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0521 09:42:52.584168 140375794652992 deprecation.py:323] From freeze.py:235: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W0521 09:42:52.584367 140375794652992 deprecation.py:323] From /home/aml/anaconda3/envs/prakasha3.6/lib/python3.6/site-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 8 variables.
# I0521 09:42:52.593511 140375794652992 graph_util_impl.py:334] Froze 8 variables.
# INFO:tensorflow:Converted 8 variables to const ops.
# I0521 09:42:52.597245 140375794652992 graph_util_impl.py:394] Converted 8 variables to const ops.
# WARNING:tensorflow:From freeze.py:188: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0521 09:42:52.598442 140375794652992 deprecation.py:323] From freeze.py:188: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:No assets to save.
# I0521 09:42:52.598898 140375794652992 builder_impl.py:640] No assets to save.
# INFO:tensorflow:No assets to write.
# I0521 09:42:52.598978 140375794652992 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: models2cnn1maxpool1fc/saved_model/saved_model.pb
# I0521 09:42:52.653880 140375794652992 builder_impl.py:425] SavedModel written to: models2cnn1maxpool1fc/saved_model/saved_model.pb

# %%
WANTED_WORDS
# Out:
# 'up,down,left,right'

# %%
import sys
# We add this path so we can import the speech processing modules.
sys.path.append("/content/tensorflow/tensorflow/examples/speech_commands/")
import input_data
import models
import numpy as np

# %%
SAMPLE_RATE = 16000
CLIP_DURATION_MS = 1000
WINDOW_SIZE_MS = 40.0
FEATURE_BIN_COUNT = 40
BACKGROUND_FREQUENCY = 0.8
BACKGROUND_VOLUME_RANGE = 0.1
TIME_SHIFT_MS = 100.0

DATA_URL = 'https://storage.googleapis.com/download.tensorflow.org/data/speech_commands_v0.02.tar.gz'
VALIDATION_PERCENTAGE = 10
TESTING_PERCENTAGE = 10

# %%
model_settings = models.prepare_model_settings(
    len(input_data.prepare_words_list(WANTED_WORDS.split(','))),
    SAMPLE_RATE, CLIP_DURATION_MS, WINDOW_SIZE_MS,
    WINDOW_STRIDE, FEATURE_BIN_COUNT, PREPROCESS)
audio_processor = input_data.AudioProcessor(
    DATA_URL, DATASET_DIR,
    SILENT_PERCENTAGE, UNKNOWN_PERCENTAGE,
    WANTED_WORDS.split(','), VALIDATION_PERCENTAGE,
    TESTING_PERCENTAGE, model_settings, LOGS_DIR)

# %%
SAVED_MODEL = '/home/aml/amlShare/DNN_M.pb'

# %%
# %tensorflow_version 1.x
import tensorflow as tf

# %%
tf.compat.v1.disable_v2_behavior()

# %%
WANTED_WORDS

# %%
tf.compat.v1.enable_eager_execution()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-650dd8b5c1e5> in <module>
# ----> 1 tf.compat.v1.enable_eager_execution()
#
# ~/anaconda3/envs/microai3.6/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in enable_eager_execution(config, device_policy, execution_mode)
#    5659         device_policy=device_policy,
#    5660         execution_mode=execution_mode,
# -> 5661         server_def=None)
#    5662
#    5663
#
# ~/anaconda3/envs/microai3.6/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in enable_eager_execution_internal(config, device_policy, execution_mode, server_def)
#    5718     if graph_mode_has_been_used:
#    5719       raise ValueError(
# -> 5720           "tf.enable_eager_execution must be called at program startup.")
#    5721   context.default_execution_mode = context.EAGER_MODE
#    5722   # pylint: disable=protected-access
#
# ValueError: tf.enable_eager_execution must be called at program startup.

# %%
with tf.compat.v1.Session() as sess:
  float_converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL)
  float_tflite_model = float_converter.convert()
  float_tflite_model_size = open(FLOAT_MODEL_TFLITE, "wb").write(float_tflite_model)
  print("Float model is %d bytes" % float_tflite_model_size)

  converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL)
  converter.optimizations = [tf.lite.Optimize.DEFAULT]
  converter.inference_input_type = tf.lite.constants.INT8
  converter.inference_output_type = tf.lite.constants.INT8
  def representative_dataset_gen():
    for i in range(100):
      data, _ = audio_processor.get_data(1, i*1, model_settings,
                                         BACKGROUND_FREQUENCY, 
                                         BACKGROUND_VOLUME_RANGE,
                                         TIME_SHIFT_MS,
                                         'testing',
                                         sess)
      flattened_data = np.array(data.flatten(), dtype=np.float32).reshape(1, 1960)
      yield [flattened_data]
  converter.representative_dataset = representative_dataset_gen
  tflite_model = converter.convert()
  tflite_model_size = open(MODEL_TFLITE, "wb").write(tflite_model)
  print("Quantized model is %d bytes" % tflite_model_size)
# Out:
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/W:0' shape=(1960, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc3/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/W:0' shape=(1960, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc3/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/W:0' shape=(1960, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc3/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/W:0' shape=(1960, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc3/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/W:0' shape=(1960, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc1/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc2/b:0' shape=(144,) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# WARNING:tensorflow:Unable to create a python object for variable <tf.Variable 'fc3/W:0' shape=(144, 144) dtype=float32_ref> because it is a reference variable. It may not be visible to training APIs. If this is a problem, consider rebuilding the SavedModel after running tf.compat.v1.enable_resource_variables().
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-2c5281e79a91> in <module>
#       1 with tf.compat.v1.Session() as sess:
#       2   float_converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL)
# ----> 3   float_tflite_model = float_converter.convert()
#       4   float_tflite_model_size = open(FLOAT_MODEL_TFLITE, "wb").write(float_tflite_model)
#       5   print("Float model is %d bytes" % float_tflite_model_size)
#
# ~/anaconda3/envs/microai3.6/lib/python3.6/site-packages/tensorflow/lite/python/lite.py in convert(self)
#     457     frozen_func, graph_def = (
#     458         _convert_to_constants.convert_variables_to_constants_v2_as_graph(
# --> 459             self._funcs[0], lower_control_flow=False))
#     460     input_tensors = [
#     461         tensor for tensor in frozen_func.inputs
#
# ~/anaconda3/envs/microai3.6/lib/python3.6/site-packages/tensorflow/python/framework/convert_to_constants.py in convert_variables_to_constants_v2_as_graph(func, lower_control_flow, aggressive_inlining)
#     704   """
#     705   graph_def, converted_inputs = _convert_variables_to_constants_v2_impl(
# --> 706       func, lower_control_flow, aggressive_inlining)
#     707   frozen_func = _construct_concrete_function(func, graph_def, converted_inputs)
#     708   return frozen_func, graph_def
#
# ~/anaconda3/envs/microai3.6/lib/python3.6/site-packages/tensorflow/python/framework/convert_to_constants.py in _convert_variables_to_constants_v2_impl(func, lower_control_flow, aggressive_inlining)
#     537       data = reference_variables[input_node.name]
#     538       dtype = attr_value_pb2.AttrValue(type=data.dtype.as_datatype_enum)
# --> 539       _populate_const_op(output_node, input_node.name, dtype, data.numpy(),
#     540                          data.shape)
#     541     # Convert Placeholder ops to Const ops.
#
# AttributeError: 'Tensor' object has no attribute 'numpy'

# %%
with tf.Session() as sess:
    train_fingerprints, train_ground_truth = audio_processor.get_data(
        FLAGS.batch_size, 0, model_settings, FLAGS.background_frequency,
        FLAGS.background_volume, time_shift_samples, 'training', sess)

# %%
import pickle

# %%
file = open("test_data.pkl",'rb')
test_data = pickle.load(file)
file = open("test_labels.pkl",'rb')
test_labels = pickle.load(file)

# %%
  float_converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL)
  float_tflite_model = float_converter.convert()
  float_tflite_model_size = open(FLOAT_MODEL_TFLITE, "wb").write(float_tflite_model)
  print("Float model is %d bytes" % float_tflite_model_size)

  converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL)
  converter.optimizations = [tf.lite.Optimize.DEFAULT]
  converter.inference_input_type = tf.lite.constants.INT8
  converter.inference_output_type = tf.lite.constants.INT8
  def representative_dataset_gen():
    for i in range(100):
      data, _ = audio_processor.get_data(1, i*1, model_settings,
                                         BACKGROUND_FREQUENCY, 
                                         BACKGROUND_VOLUME_RANGE,
                                         TIME_SHIFT_MS,
                                         'testing',
                                         sess)
      flattened_data = np.array(data.flatten(), dtype=np.float32).reshape(1, 1960)
      yield [flattened_data]
  converter.representative_dataset = representative_dataset_gen
  tflite_model = converter.convert()
  tflite_model_size = open(MODEL_TFLITE, "wb").write(tflite_model)
  print("Quantized model is %d bytes" % tflite_model_size)

# %%
test_data.shape
test_labels.shape
# Out:
# (2213, 1960)

# %%
# Out:
# (2213,)

# %%
# Helper function to run inference
def run_tflite_inference(tflite_model_path, test_data,test_labels,model_type="Float",):
  # Load test data
  np.random.seed(0) # set random seed for reproducible test results.

  test_data = np.expand_dims(test_data, axis=1).astype(np.float32)

  # Initialize the interpreter
  interpreter = tf.lite.Interpreter(tflite_model_path)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]
  print(input_details)  
  print(output_details)

  # For quantized models, manually quantize the input data from float to integer
  if model_type == "Quantized":
    input_scale, input_zero_point = input_details["quantization"]
    test_data = test_data / input_scale + input_zero_point
    test_data = test_data.astype(input_details["dtype"])

  correct_predictions = 0
  for i in range(len(test_data)):
    interpreter.set_tensor(input_details["index"], test_data[i])
    interpreter.invoke()
    output = interpreter.get_tensor(output_details["index"])[0]
    top_prediction = output.argmax()
    correct_predictions += (top_prediction == test_labels[i])

  print('%s model accuracy is %f%% (Number of test samples=%d)' % (
      model_type, (correct_predictions * 100) / len(test_data), len(test_data)))


run_tflite_inference(FLOAT_MODEL_TFLITE,test_data,test_labels,model_type='Float')

# Compute quantized model accuracy
run_tflite_inference(MODEL_TFLITE,test_data,test_labels, model_type='Quantized')
# Out:
# {'name': 'Reshape_1', 'index': 8, 'shape': array([   1, 1960], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0)}
# {'name': 'labels_softmax', 'index': 15, 'shape': array([1, 4], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0)}
# Float model accuracy is 27.022142% (Number of test samples=2213)
# {'name': 'Reshape_1', 'index': 8, 'shape': array([   1, 1960], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (0.10830269753932953, -128)}
# {'name': 'labels_softmax', 'index': 18, 'shape': array([1, 8], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (0.00390625, -128)}
# Quantized model accuracy is 87.031179% (Number of test samples=2213)

# %%
import numpy as np

# %%
# Compute float model accuracy
run_tflite_inference(FLOAT_MODEL_TFLITE,test_data,test_labels,model_type='Float')

# Compute quantized model accuracy
run_tflite_inference(MODEL_TFLITE,test_data,test_labels, model_type='Quantized')
# Out:
# {'name': 'Reshape_1', 'index': 8, 'shape': array([   1, 1960], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0)}
# {'name': 'labels_softmax', 'index': 15, 'shape': array([1, 4], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0)}
# Float model accuracy is 27.022142% (Number of test samples=2213)
# {'name': 'Reshape_1', 'index': 8, 'shape': array([   1, 1960], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (0.10830269753932953, -128)}
# {'name': 'labels_softmax', 'index': 18, 'shape': array([1, 8], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (0.00390625, -128)}
# Quantized model accuracy is 87.031179% (Number of test samples=2213)

# %%
MODEL_TFLITE = 'cnn/model.tflite'
MODEL_TFLITE_MICRO = 'cnn/model.cc'

# %%
# !xxd -i {MODEL_TFLITE} > {MODEL_TFLITE_MICRO}
# Update variable names
REPLACE_TEXT = MODEL_TFLITE.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'/g_model/g' {MODEL_TFLITE_MICRO}
